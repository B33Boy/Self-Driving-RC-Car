# %%
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import cv2

# %%
# %matplotlib inline

#Take the first .npz file for testing
training_data = glob.glob('../training_data/*.npz')[0]
print(training_data)


with np.load(training_data) as data:
    X_temp = data['train'][5]
    y_temp = data['train_labels']
    
    
    img = X_temp.reshape(120, 320).astype(np.float32)
    plt.imshow(img,cmap='gray')
    plt.show()
    
    #Flip along the vertical axis
    rev = cv2.flip(img, 1)
    plt.imshow(rev,cmap='gray')
    plt.show()
# Out:
# ../training_data\1536497862.npz
